# %% [markdown]
# <a href="https://colab.research.google.com/github/sikandarmir/Data_Upload_into_Colab/blob/main/import_data_from_google_drive.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # In this Section We discuss That how to import data from google drive

# %%
import cv2
from google.colab.patches import cv2_imshow

# %% [markdown]
# connect your google drive for that right click on the file and than click on the driver.{Note:That you were login into your google driver account.}

# %%
driver_data=cv2.imread("/content/drive/MyDrive/Data_set/Train_data/Yes/LMM13_orig.jpg")
cv2_imshow(driver_data)
# Out:
# <PIL.Image.Image image mode=RGB size=1078x1605 at 0x7F055C3B2790>
